# %%
import pandas as pd
import numpy as np
import glob

# %%
big_df = pd.DataFrame() 
    
for filename in glob.glob("./Rating_*.xlsx"):
#    connres.commit()
    print ("READING DATABASE: "+filename)
    df = pd.read_excel(open(filename,'rb'), sheet_name="Resultados",header = None) #Reading SABI Export without index  
    df.columns = ['id', 'nombre_x', 'nif', 'nombre', 'provincia', 'calle', 'telefono', 'web', 'desc_actividad', 'cnae', 'cod_consolidacion', 'rating_grade_h2', 'rating_grade_h1', 'rating_grade_h0', 'rating_numerico_h2', 'rating_numerico_h1', 'rating_numerico_h0', 'modelo_propension_h2', 'modelo_propension_h1', 'modelo_propension_h0', 'guo_nombre', 'guo_id_bvd', 'guo_pais', 'guo_tipo', 'estado_detallado', 'fecha_cambio_estado', 'fecha_constitucion', 'p10000_h0', 'p10000_h1', 'p10000_h2', 'p20000_h0', 'p20000_h1', 'p20000_h2', 'p31200_h0', 'p31200_h1', 'p31200_h2', 'p32300_h0', 'p32300_h1', 'p32300_h2', 'p40100_mas_40500_h0', 'p40100_mas_40500_h1', 'p40100_mas_40500_h2', 'p40800_h0', 'p40800_h1', 'p40800_h2', 'p49100_h0', 'p49100_h1', 'p49100_h2']
    df['h0_anio'] = 2017     
    df = df.fillna('')
    df=df.drop(df.index[0]) #Dropping SABI variable names.
    df['nif'] = df.nif.str.upper() #CONVERTING cif INTO UPPERCASE
    for partida in ['p10000_h0', 'p10000_h1', 'p10000_h2', 'p20000_h0', 'p20000_h1', 'p20000_h2', 'p31200_h0', 'p31200_h1', 'p31200_h2', 'p32300_h0', 'p32300_h1', 'p32300_h2', 'p40100_mas_40500_h0', 'p40100_mas_40500_h1', 'p40100_mas_40500_h2', 'p40800_h0', 'p40800_h1', 'p40800_h2', 'p49100_h0', 'p49100_h1', 'p49100_h2']:
#        print (partida,"ha sido convertido en numerico")
        df[partida] = pd.to_numeric(df[partida], errors='coerce').fillna(0)- 0.005
    df['nif_normalizado'] = df['nif'].str[-8:]    
    big_df = big_df.append(df, ignore_index=True)
# Out:
# READING DATABASE: ./Rating_1.xlsx
# READING DATABASE: ./Rating_3.xlsx
# READING DATABASE: ./Rating_2.xlsx
# READING DATABASE: ./Rating_5.xlsx
# READING DATABASE: ./Rating_4.xlsx

# %%
df = big_df
df['target_status'] = [0 if i in ['Activa', ''] else 1 for i in df['estado_detallado']] # 0 si Activa, 1 si algo raro!

# _h0, _h1, _h2
# _h0: history 0, here h0 means the year 2017 (historia 0, aquí h0 significa el año 2017)
# _h1: history -1, here h1 means the year 2016 (historia -1, aquí h1 significa el año 2016)
# _h2: history -2, here h2 means the year 2015 (historia -2, aquí h2 significa el año 2015)

# Ebita Margin - Ebitda / Turn over (Ventas)
# p49100: Profit (Resultado del ejercicio)
# p40800: Amortization (Amortización) 
# p40100: Sales Turnover (Ingresos de Explotación)
# p40500: Other sales (Otros Ingresos)
df['ebitda_income'] = (df.p49100_h1+df.p40800_h1)/(df.p40100_mas_40500_h1)

# %%
# Total Debt / Ebita 
# p31200: Short Term Debt / Deuda a corto plazo
# p32300: Long Term Debt / Deuda a largo plazo
# p49100: Profit (Resultado del ejercicio)
# p40800: Amortization (Amortización) 
df['debt_ebitda'] =(df.p31200_h1 + df.p32300_h1) /(df.p49100_h1+df.p40800_h1) 

# rraa_rrpp: Financial leveraging / apalancamiento financiero 
# p10000: Total Assets / Total activos
# p20000: Own Capital / Patrimonio neto
df['rraa_rrpp'] = (df.p10000_h1 - df.p20000_h1) /df.p20000_h1

# Log of Operating Income
df['log_operating_income'] = np.log(df.p40100_mas_40500_h1)
# Out:
# /Users/ocon/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:853: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/ocon/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:853: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(random_state=1234)

df_clean = df[['ebitda_income','debt_ebitda','rraa_rrpp','log_operating_income','target_status']].replace([np.inf, -np.inf], np.nan).dropna()
X = df_clean[['ebitda_income','debt_ebitda','rraa_rrpp','log_operating_income']]
y = df_clean['target_status']

fitted_model = model.fit(X, y)
y_pred = fitted_model.predict(X)
y_pred_proba = fitted_model.predict_proba(X)[:,1]

print ("ASSESSING THE MODEL...")
# CALCULATING GINI PERFORMANCE ON DEVELOPMENT SAMPLE
from sklearn.metrics import roc_auc_score
gini_score = 2*roc_auc_score(y, y_pred_proba)-1
print ("GINI DEVELOPMENT=", gini_score)

from sklearn.metrics import accuracy_score
print("Accuracy: {0}".format(accuracy_score(y_pred,y)))

print ("SAVING THE PERSISTENT MODEL...")
from joblib import dump#, load
dump(fitted_model, 'Rating_RandomForestClassifier.joblib')
# Out:
# /Users/ocon/opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ASSESSING THE MODEL...
# GINI DEVELOPMENT= 0.9995292707650925
# Accuracy: 0.9823664311392091
# SAVING THE PERSISTENT MODEL...
# ['Rating_RandomForestClassifier.joblib']

# %%
df_clean
# Out:
#        ebitda_income  debt_ebitda  rraa_rrpp  log_operating_income  \
# 0          -0.079507   -14.440431   3.355857             17.777732
# 2          -0.017321   -29.773463   1.084172             17.390073
# 4           0.022305    12.806176   5.693514             17.294808
# 5           0.049154    22.145202   1.622587             17.210947
# 6           0.133570     0.858181   0.441393             16.981112
# ...              ...          ...        ...                   ...
# 49990       0.000478   281.880578   2.221657              8.589851
# 49991      -0.001202  -106.253456   1.034530              8.689298
# 49994      -0.028258    -8.612671   2.855977              8.368109
# 49995      -0.001935   -20.042590   1.047479              8.727246
# 49999      -0.004487   -36.291654  -1.455817              8.628924
#
#        target_status
# 0                  0
# 2                  0
# 4                  0
# 5                  0
# 6                  0
# ...              ...
# 49990              0
# 49991              0
# 49994              0
# 49995              0
# 49999              0
#
# [32268 rows x 5 columns]

# %%
df.T
# Out:
#                                                                   0      \
# id                                                                    1
# nombre_x                                                 Telefonica, SA
# nif                                                           A28015865
# nombre                                                   Telefonica, SA
# provincia                                                        Madrid
# calle                                            CALLE GRAN VIA, 28 - 5
# telefono                                                 +34 90/0111004
# web                                                   www.telefonica.es
# desc_actividad        Se dedica a la instalacion y explotacion de se...
# cnae                                                               6420
# cod_consolidacion                                                    C2
# rating_grade_h2                                                      B-
# rating_grade_h1                                                       B
# rating_grade_h0                                                      B+
# rating_numerico_h2                                               4.2202
# rating_numerico_h1                                               4.5936
# rating_numerico_h0                                              4.92757
# modelo_propension_h2                                            57.1916
# modelo_propension_h1                                            56.4884
# modelo_propension_h0                                            51.0379
# guo_nombre                                               TELEFONICA, SA
# guo_id_bvd                                                  ESA28015865
# guo_pais                                                             ES
# guo_tipo                                                        Empresa
# estado_detallado                                                 Activa
# fecha_cambio_estado                                 1998-03-17 00:00:00
# fecha_constitucion                                  1924-04-19 00:00:00
# p10000_h0                                                   1.15066e+08
# p10000_h1                                                   1.23641e+08
# p10000_h2                                                   1.20329e+08
# p20000_h0                                                    2.6618e+07
# p20000_h1                                                    2.8385e+07
# p20000_h2                                                    2.5436e+07
# p31200_h0                                                    4.6332e+07
# p31200_h1                                                    4.5612e+07
# p31200_h2                                                    4.7117e+07
# p32300_h0                                                     9.414e+06
# p32300_h1                                                    1.4749e+07
# p32300_h2                                                     1.297e+07
# p40100_mas_40500_h0                                          5.2455e+07
# p40100_mas_40500_h1                                          5.2574e+07
# p40100_mas_40500_h2                                          5.5665e+07
# p40800_h0                                                    -9.396e+06
# p40800_h1                                                    -9.649e+06
# p40800_h2                                                    -9.704e+06
# p49100_h0                                                     6.791e+06
# p49100_h1                                                     5.469e+06
# p49100_h2                                                     3.525e+06
# h0_anio                                                            2017
# nif_normalizado                                                28015865
# target_status                                                         0
# ebitda_income                                                 -0.079507
# debt_ebitda                                                    -14.4404
# rraa_rrpp                                                       3.35586
# log_operating_income                                            17.7777
#
#                                        1      \
# id                                         2
# nombre_x                  Banco Santander SA
# nif                                A39000013
# nombre                    Banco Santander SA
# provincia                          Cantabria
# calle                 PASEO PEREDA, 9 - - 12
# telefono                      +34 94/2206100
# web                   www.gruposantander.com
# desc_actividad
# cnae                                    6419
# cod_consolidacion                         C2
# rating_grade_h2                         CCC-
# rating_grade_h1                         CCC-
# rating_grade_h0                         CCC-
# rating_numerico_h2                   3.04508
# rating_numerico_h1                   3.04508
# rating_numerico_h0                   3.04508
# modelo_propension_h2                 19.2838
# modelo_propension_h1                 16.5209
# modelo_propension_h0                 19.2838
# guo_nombre                BANCO SANTANDER SA
# guo_id_bvd                       ESA39000013
# guo_pais                                  ES
# guo_tipo                               Banco
# estado_detallado
# fecha_cambio_estado
# fecha_constitucion                21/03/1857
# p10000_h0                        1.44430e+09
# p10000_h1                        1.33912e+09
# p10000_h2                        1.34026e+09
# p20000_h0                        1.06833e+08
# p20000_h1                        1.02699e+08
# p20000_h2                         9.8753e+07
# p31200_h0                                  0
# p31200_h1                                  0
# p31200_h2                                  0
# p32300_h0                                  0
# p32300_h1                                  0
# p32300_h2                                  0
# p40100_mas_40500_h0               5.0321e+07
# p40100_mas_40500_h1               4.6192e+07
# p40100_mas_40500_h2                4.813e+07
# p40800_h0                                  0
# p40800_h1                                  0
# p40800_h2                                  0
# p49100_h0                                  0
# p49100_h1                                  0
# p49100_h2                                  0
# h0_anio                                 2017
# nif_normalizado                     39000013
# target_status                              0
# ebitda_income                              0
# debt_ebitda                              NaN
# rraa_rrpp                            12.0393
# log_operating_income                 17.6483
#
#                                                                   2      \
# id                                                                    3
# nombre_x                                                     Repsol SA.
# nif                                                           A78374725
# nombre                                                       Repsol SA.
# provincia                                                        Madrid
# calle                                           CALLE MENDEZ ALVARO, 44
# telefono                                                 +34 91/7538100
# web                                                      www.repsol.com
# desc_actividad        LA INVESTIGACION, EXPLOTACION, IMPORTACION, AL...
# cnae                                                               7010
# cod_consolidacion                                                    C2
# rating_grade_h2                                                    CCC+
# rating_grade_h1                                                      BB
# rating_grade_h0                                                    BBB-
# rating_numerico_h2                                              3.63524
# rating_numerico_h1                                              5.54096
# rating_numerico_h0                                              6.36059
# modelo_propension_h2                                            45.8093
# modelo_propension_h1                                            47.4608
# modelo_propension_h0                                            49.7684
# guo_nombre                                                   REPSOL SA.
# guo_id_bvd                                                  ESA78374725
# guo_pais                                                             ES
# guo_tipo                                                        Empresa
# estado_detallado                                                 Activa
# fecha_cambio_estado                                 2000-06-28 00:00:00
# fecha_constitucion                                  1986-11-12 00:00:00
# p10000_h0                                                    5.9857e+07
# p10000_h1                                                    6.4849e+07
# p10000_h2                                                    6.3077e+07
# p20000_h0                                                    3.0067e+07
# p20000_h1                                                    3.1115e+07
# p20000_h2                                                    2.8696e+07
# p31200_h0                                                    1.1875e+07
# p31200_h1                                                    1.1491e+07
# p31200_h2                                                    1.2523e+07
# p32300_h0                                                     4.206e+06
# p32300_h1                                                     6.909e+06
# p32300_h2                                                     7.073e+06
# p40100_mas_40500_h0                                          4.2378e+07
# p40100_mas_40500_h1                                          3.5679e+07
# p40100_mas_40500_h2                                          4.2265e+07
# p40800_h0                                                    -2.399e+06
# p40800_h1                                                    -2.529e+06
# p40800_h2                                                    -2.988e+06
# p49100_h0                                                     2.789e+06
# p49100_h1                                                     1.911e+06
# p49100_h2                                                     -2.44e+06
# h0_anio                                                            2017
# nif_normalizado                                                78374725
# target_status                                                         0
# ebitda_income                                                -0.0173211
# debt_ebitda                                                    -29.7735
# rraa_rrpp                                                       1.08417
# log_operating_income                                            17.3901
#
#                                                                   3      \
# id                                                                    4
# nombre_x                                 Peugeot España SA (Extinguida)
# nif                                                           A32001166
# nombre                                   Peugeot España SA (Extinguida)
# provincia                                                        Madrid
# calle                                        CALLE PUERTO DE SOMPORT, 8
# telefono                                                 +34 91/3472000
# web                                                      www.peugeot.es
# desc_actividad               Comercialización de automóviles y camiones
# cnae                                                               4511
# cod_consolidacion                                                    C2
# rating_grade_h2                                                     CC+
# rating_grade_h1                                                     CC+
# rating_grade_h0                                                     CC+
# rating_numerico_h2                                              2.74606
# rating_numerico_h1                                              2.74606
# rating_numerico_h0                                              2.74606
# modelo_propension_h2                                            16.5209
# modelo_propension_h1                                            16.5209
# modelo_propension_h0                                            16.5209
# guo_nombre
# guo_id_bvd
# guo_pais
# guo_tipo
# estado_detallado      Extinción: La empresa se encuentra en situació...
# fecha_cambio_estado                                 2017-10-11 00:00:00
# fecha_constitucion                                  1954-03-16 00:00:00
# p10000_h0                                                             0
# p10000_h1                                                             0
# p10000_h2                                                             0
# p20000_h0                                                             0
# p20000_h1                                                             0
# p20000_h2                                                             0
# p31200_h0                                                             0
# p31200_h1                                                             0
# p31200_h2                                                             0
# p32300_h0                                                             0
# p32300_h1                                                             0
# p32300_h2                                                             0
# p40100_mas_40500_h0                                                   0
# p40100_mas_40500_h1                                                   0
# p40100_mas_40500_h2                                                   0
# p40800_h0                                                             0
# p40800_h1                                                             0
# p40800_h2                                                             0
# p49100_h0                                                             0
# p49100_h1                                                             0
# p49100_h2                                                             0
# h0_anio                                                            2017
# nif_normalizado                                                32001166
# target_status                                                         1
# ebitda_income                                                       NaN
# debt_ebitda                                                         NaN
# rraa_rrpp                                                           NaN
# log_operating_income                                               -inf
#
#                                                                   4      \
# id                                                                    5
# nombre_x               Acs, Actividades De Construccion Y Servicios, SA
# nif                                                           A28004885
# nombre                 Acs, Actividades De Construccion Y Servicios, SA
# provincia                                                        Madrid
# calle                                              AVENIDA PIO XII, 102
# telefono                                                 +34 91/3439200
# web                                                    www.grupoacs.com
# desc_actividad        " ARTICULO 4.? LA SOCIEDAD TIENE POR OBJETO: 1...
# cnae                                                               4299
# cod_consolidacion                                                    C2
# rating_grade_h2                                                      B+
# rating_grade_h1                                                       B
# rating_grade_h0                                                      BB
# rating_numerico_h2                                              4.69025
# rating_numerico_h1                                              4.58452
# rating_numerico_h0                                              5.40837
# modelo_propension_h2                                            53.9921
# modelo_propension_h1                                            46.0274
# modelo_propension_h0                                            57.8573
# guo_nombre             ACS, ACTIVIDADES DE CONSTRUCCION Y SERVICIOS, SA
# guo_id_bvd                                                  ESA28004885
# guo_pais                                                             ES
# guo_tipo                                                        Empresa
# estado_detallado                                                 Activa
# fecha_cambio_estado                                 1997-10-24 00:00:00
# fecha_constitucion                                  1942-10-13 00:00:00
# p10000_h0                                                   3.18807e+07
# p10000_h1                                                   3.33733e+07
# p10000_h2                                                   3.52798e+07
# p20000_h0                                                   5.16804e+06
# p20000_h1                                                   4.98591e+06
# p20000_h2                                                   5.25604e+06
# p31200_h0                                                   5.03371e+06
# p31200_h1                                                   4.97718e+06
# p31200_h2                                                   7.47704e+06
# p32300_h0                                                    2.8891e+06
# p32300_h1                                                   4.28803e+06
# p32300_h2                                                   3.49196e+06
# p40100_mas_40500_h0                                         3.52188e+07
# p40100_mas_40500_h1                                         3.24369e+07
# p40100_mas_40500_h2                                         3.53458e+07
# p40800_h0                                                       -611218
# p40800_h1                                                       -513934
# p40800_h2                                                       -788001
# p49100_h0                                                   1.32923e+06
# p49100_h1                                                   1.23743e+06
# p49100_h2                                                    1.2213e+06
# h0_anio                                                            2017
# nif_normalizado                                                28004885
# target_status                                                         0
# ebitda_income                                                 0.0223047
# debt_ebitda                                                     12.8062
# rraa_rrpp                                                       5.69351
# log_operating_income                                            17.2948
#
#                                                                   5      \
# id                                                                    6
# nombre_x                                    Iberdrola, Sociedad Anonima
# nif                                                           A48010615
# nombre                                      Iberdrola, Sociedad Anonima
# provincia                                                       Vizcaya
# calle                                PLAZA EUSKADI, 5 - TORRE IBERDROLA
# telefono                                                 +34 94/4151411
# web                                                    www.iberdrola.es
# desc_actividad        COMERCIALIZACION DE ENERGIA ELECTRICA, DISTRIB...
# cnae                                                               6420
# cod_consolidacion                                                    C2
# rating_grade_h2                                                      BB
# rating_grade_h1                                                      BB
# rating_grade_h0                                                     BB-
# rating_numerico_h2                                              5.59298
# rating_numerico_h1                                              5.59298
# rating_numerico_h0                                               5.3273
# modelo_propension_h2                                             57.521
# modelo_propension_h1                                            52.7644
# modelo_propension_h0                                            58.1354
# guo_nombre                                  IBERDROLA, SOCIEDAD ANONIMA
# guo_id_bvd                                                  ESA48010615
# guo_pais                                                             ES
# guo_tipo                                                        Empresa
# estado_detallado                                                 Activa
# fecha_cambio_estado                                 1993-04-22 00:00:00
# fecha_constitucion                                  1901-07-19 00:00:00
# p10000_h0                                                   1.10689e+08
# p10000_h1                                                   1.06706e+08
# p10000_h2                                                   1.04664e+08
# p20000_h0                                                   4.27332e+07
# p20000_h1                                                   4.06874e+07
# p20000_h2                                                   4.09561e+07
# p31200_h0                                                   2.97847e+07
# p31200_h1                                                   2.69705e+07
# p31200_h2                                                    2.4899e+07
# p32300_h0                                                   7.50981e+06
# p32300_h1                                                   5.49751e+06
# p32300_h2                                                   5.66202e+06
# p40100_mas_40500_h0                                         3.18429e+07
# p40100_mas_40500_h1                                         2.98277e+07
# p40100_mas_40500_h2                                         3.19658e+07
# p40800_h0                                                  -4.60607e+06
# p40800_h1                                                  -3.08789e+06
# p40800_h2                                                  -3.47661e+06
# p49100_h0                                                   2.99168e+06
# p49100_h1                                                   4.55404e+06
# p49100_h2                                                   3.95436e+06
# h0_anio                                                            2017
# nif_normalizado                                                48010615
# target_status                                                         0
# ebitda_income                                                 0.0491538
# debt_ebitda                                                     22.1452
# rraa_rrpp                                                       1.62259
# log_operating_income                                            17.2109
#
#                                                                   6      \
# id                                                                    7
# nombre_x                                      Pontegadea Inversiones SL
# nif                                                           B15792286
# nombre                                        Pontegadea Inversiones SL
# provincia                                                      a Coruña
# calle                                           AVENIDA DEPUTACION, S/N
# telefono                                                 +34 98/1185344
# web
# desc_actividad        PARTICIPACION EN SOCIEDADES MERCANTILES ASI CO...
# cnae                                                               7010
# cod_consolidacion                                                    C2
# rating_grade_h2                                                     AA-
# rating_grade_h1                                                      A+
# rating_grade_h0                                                     AA-
# rating_numerico_h2                                              8.46302
# rating_numerico_h1                                              8.09492
# rating_numerico_h0                                                8.363
# modelo_propension_h2                                            55.5179
# modelo_propension_h1                                             49.073
# modelo_propension_h0                                            54.0045
# guo_nombre                                            MR AMANCIO ORTEGA
# guo_id_bvd                                                 ESP002179616
# guo_pais                                                             ES
# guo_tipo                          Una o más personas físicas o familias
# estado_detallado                                                 Activa
# fecha_cambio_estado                                 2001-06-08 00:00:00
# fecha_constitucion                                  2001-06-08 00:00:00
# p10000_h0                                                    2.9028e+07
# p10000_h1                                                    2.8394e+07
# p10000_h2                                                    2.4859e+07
# p20000_h0                                                    2.1006e+07
# p20000_h1                                                    1.9699e+07
# p20000_h2                                                    1.7535e+07
# p31200_h0                                                      1.72e+06
# p31200_h1                                                     2.168e+06
# p31200_h2                                                     1.417e+06
# p32300_h0                                                        260000
# p32300_h1                                                        549000
# p32300_h2                                                        514000
# p40100_mas_40500_h0                                          2.5783e+07
# p40100_mas_40500_h1                                          2.3703e+07
# p40100_mas_40500_h2                                          2.1293e+07
# p40800_h0                                                    -1.234e+06
# p40800_h1                                                    -1.066e+06
# p40800_h2                                                    -1.063e+06
# p49100_h0                                                     4.161e+06
# p49100_h1                                                     4.232e+06
# p49100_h2                                                     3.875e+06
# h0_anio                                                            2017
# nif_normalizado                                                15792286
# target_status                                                         0
# ebitda_income                                                   0.13357
# debt_ebitda                                                    0.858181
# rraa_rrpp                                                      0.441393
# log_operating_income                                            16.9811
#
#                                                                   7      \
# id                                                                    8
# nombre_x                                  Industria De Diseño Textil SA
# nif                                                           A15075062
# nombre                                    Industria De Diseño Textil SA
# provincia                                                      a Coruña
# calle                 AVENIDA DEPUTACION ((PG IND DE SABON) - EDIF. ...
# telefono                                                 +34 98/1185400
# web                                                     www.inditex.com
# desc_actividad                   Comercialización de productos textíles
# cnae                                                               4642
# cod_consolidacion                                                    C2
# rating_grade_h2                                                     AA+
# rating_grade_h1                                                     AA+
# rating_grade_h0                                                      AA
# rating_numerico_h2                                              9.08904
# rating_numerico_h1                                              9.01995
# rating_numerico_h0                                              8.88082
# modelo_propension_h2                                            46.7721
# modelo_propension_h1                                             42.975
# modelo_propension_h0                                            52.8188
# guo_nombre                                            MR AMANCIO ORTEGA
# guo_id_bvd                                                 ESP002179616
# guo_pais                                                             ES
# guo_tipo                          Una o más personas físicas o familias
# estado_detallado                                                 Activa
# fecha_cambio_estado                                 1985-06-12 00:00:00
# fecha_constitucion                                  1985-06-12 00:00:00
# p10000_h0                                                    2.0231e+07
# p10000_h1                                                   1.96214e+07
# p10000_h2                                                   1.73571e+07
# p20000_h0                                                    1.3522e+07
# p20000_h1                                                   1.27516e+07
# p20000_h2                                                   1.14508e+07
# p31200_h0                                                     1.009e+06
# p31200_h1                                                           498
# p31200_h2                                                           749
# p32300_h0                                                        116000
# p32300_h1                                                        125382
# p32300_h2                                                         78790
# p40100_mas_40500_h0                                          2.5336e+07
# p40100_mas_40500_h1                                         2.33105e+07
# p40100_mas_40500_h2                                         2.09004e+07
# p40800_h0                                                       -963000
# p40800_h1                                                       -967985
# p40800_h2                                                       -956829
# p49100_h0                                                     4.314e+06
# p49100_h1                                                   4.02073e+06
# p49100_h2                                                   3.67744e+06
# h0_anio                                                            2017
# nif_normalizado                                                15075062
# target_status                                                         0
# ebitda_income                                                   0.13096
# debt_ebitda                                                    0.041235
# rraa_rrpp                                                      0.538749
# log_operating_income                                            16.9644
#
#                                                                  8      \
# id                                                                   9
# nombre_x              Banco Bilbao Vizcaya Argentaria Sociedad Anonima
# nif                                                          A48265169
# nombre                Banco Bilbao Vizcaya Argentaria Sociedad Anonima
# provincia                                                      Vizcaya
# calle                                             PLAZA SAN NICOLAS, 4
# telefono                                                +34 94/4876000
# web                                                       www.bbva.com
# desc_actividad
# cnae                                                              6419
# cod_consolidacion                                                   C2
# rating_grade_h2                                                   CCC-
# rating_grade_h1                                                   CCC-
# rating_grade_h0                                                   CCC-
# rating_numerico_h2                                             3.04508
# rating_numerico_h1                                             3.04508
# rating_numerico_h0                                             3.04508
# modelo_propension_h2                                           19.2838
# modelo_propension_h1                                           19.2838
# modelo_propension_h0                                           19.2838
# guo_nombre            BANCO BILBAO VIZCAYA ARGENTARIA SOCIEDAD ANONIMA
# guo_id_bvd                                                 ESA48265169
# guo_pais                                                            ES
# guo_tipo                                                         Banco
# estado_detallado
# fecha_cambio_estado
# fecha_constitucion                                 1988-10-01 00:00:00
# p10000_h0                                                  6.90059e+08
# p10000_h1                                                  7.31856e+08
# p10000_h2                                                  7.50078e+08
# p20000_h0                                                   5.3323e+07
# p20000_h1                                                   5.5428e+07
# p20000_h2                                                   5.5439e+07
# p31200_h0                                                            0
# p31200_h1                                                            0
# p31200_h2                                                            0
# p32300_h0                                                            0
# p32300_h1                                                            0
# p32300_h2                                                            0
# p40100_mas_40500_h0                                         2.7495e+07
# p40100_mas_40500_h1                                         2.6781e+07
# p40100_mas_40500_h2                                         2.5646e+07
# p40800_h0                                                            0
# p40800_h1                                                            0
# p40800_h2                                                            0
# p49100_h0                                                            0
# p49100_h1                                                            0
# p49100_h2                                                            0
# h0_anio                                                           2017
# nif_normalizado                                               48265169
# target_status                                                        0
# ebitda_income                                                        0
# debt_ebitda                                                        NaN
# rraa_rrpp                                                      12.2037
# log_operating_income                                           17.1032
#
#                                                                   9      ...  \
# id                                                                   10  ...
# nombre_x                                       Naturgy Energy Group SA.  ...
# nif                                                           A08015497  ...
# nombre                                         Naturgy Energy Group SA.  ...
# provincia                                                        Madrid  ...
# calle                                              AVENIDA SAN LUIS, 77  ...
# telefono                                                 +34 90/0100251  ...
# web                                                     www.naturgy.com  ...
# desc_actividad        El negocio del gas, de la electricidad y de cu...  ...
# cnae                                                               6420  ...
# cod_consolidacion                                                    C2  ...
# rating_grade_h2                                                     BB+  ...
# rating_grade_h1                                                     BB+  ...
# rating_grade_h0                                                      BB  ...
# rating_numerico_h2                                              6.08745  ...
# rating_numerico_h1                                              5.80188  ...
# rating_numerico_h0                                              5.60117  ...
# modelo_propension_h2                                             62.959  ...
# modelo_propension_h1                                            52.6599  ...
# modelo_propension_h0                                            57.7802  ...
# guo_nombre                                     NATURGY ENERGY GROUP SA.  ...
# guo_id_bvd                                                  ESA08015497  ...
# guo_pais                                                             ES  ...
# guo_tipo                                                        Empresa  ...
# estado_detallado                                                 Activa  ...
# fecha_cambio_estado                                 1992-05-13 00:00:00  ...
# fecha_constitucion                                  1943-01-28 00:00:00  ...
# p10000_h0                                                    4.7322e+07  ...
# p10000_h1                                                    4.7114e+07  ...
# p10000_h2                                                    4.8132e+07  ...
# p20000_h0                                                    1.8426e+07  ...
# p20000_h1                                                    1.9005e+07  ...
# p20000_h2                                                    1.8518e+07  ...
# p31200_h0                                                    1.7126e+07  ...
# p31200_h1                                                    1.5003e+07  ...
# p31200_h2                                                    1.5653e+07  ...
# p32300_h0                                                     2.884e+06  ...
# p32300_h1                                                     2.599e+06  ...
# p32300_h2                                                     2.595e+06  ...
# p40100_mas_40500_h0                                          2.3544e+07  ...
# p40100_mas_40500_h1                                          2.3449e+07  ...
# p40100_mas_40500_h2                                          2.6272e+07  ...
# p40800_h0                                                    -1.648e+06  ...
# p40800_h1                                                    -1.759e+06  ...
# p40800_h2                                                     -1.75e+06  ...
# p49100_h0                                                     2.112e+06  ...
# p49100_h1                                                     3.006e+06  ...
# p49100_h2                                                     3.261e+06  ...
# h0_anio                                                            2017  ...
# nif_normalizado                                                08015497  ...
# target_status                                                         0  ...
# ebitda_income                                                 0.0531792  ...
# debt_ebitda                                                     14.1155  ...
# rraa_rrpp                                                       1.47903  ...
# log_operating_income                                            16.9703  ...
#
#                                                       49990  \
# id                                                    11895
# nombre_x                                  Sergi Armengol SL
# nif                                               B25350521
# nombre                                    Sergi Armengol SL
# provincia                                            Lleida
# calle                                CALLE DELS BATEDORS, 6
# telefono                                     +34 97/3390377
# web
# desc_actividad               Explotación de ganado porcino.
# cnae                                                   0149
# cod_consolidacion                                        U1
# rating_grade_h2                                          BB
# rating_grade_h1                                          BB
# rating_grade_h0                                        BBB-
# rating_numerico_h2                                  5.60543
# rating_numerico_h1                                  5.60888
# rating_numerico_h0                                  6.45906
# modelo_propension_h2                                50.0915
# modelo_propension_h1                                57.7748
# modelo_propension_h0                                44.9837
# guo_nombre                         SERGI ARMENGOL SANTACREU
# guo_id_bvd                                     ES*339326246
# guo_pais                                                 ES
# guo_tipo              Una o más personas físicas o familias
# estado_detallado                                     Activa
# fecha_cambio_estado                     1995-05-10 00:00:00
# fecha_constitucion                      1995-05-10 00:00:00
# p10000_h0                                           2725.77
# p10000_h1                                           2634.66
# p10000_h2                                           2267.42
# p20000_h0                                           1030.31
# p20000_h1                                           817.797
# p20000_h2                                           739.443
# p31200_h0                                            194.16
# p31200_h1                                           409.589
# p31200_h2                                           438.061
# p32300_h0                                           193.148
# p32300_h1                                           315.236
# p32300_h2                                           232.476
# p40100_mas_40500_h0                                  6636.6
# p40100_mas_40500_h1                                 5376.81
# p40100_mas_40500_h2                                 5082.26
# p40800_h0                                          -143.287
# p40800_h1                                          -114.486
# p40800_h2                                          -85.6604
# p49100_h0                                           293.603
# p49100_h1                                           117.058
# p49100_h2                                           103.113
# h0_anio                                                2017
# nif_normalizado                                    25350521
# target_status                                             0
# ebitda_income                                   0.000478237
# debt_ebitda                                         281.881
# rraa_rrpp                                           2.22166
# log_operating_income                                8.58985
#
#                                                                   49991  \
# id                                                                11896
# nombre_x                           Transportes Antonio Santo Domingo SL
# nif                                                           B40212185
# nombre                             Transportes Antonio Santo Domingo SL
# provincia                                                       Segovia
# calle                       CALLE FRESNO (POL INDUSTRIAL NICOMEDES), 58
# telefono                                                 +34 92/1428799
# web                                                        www.sdlog.es
# desc_actividad        Transporte nacional e internacional de mercanc...
# cnae                                                               4941
# cod_consolidacion                                                    U1
# rating_grade_h2                                                    BBB-
# rating_grade_h1                                                    BBB-
# rating_grade_h0                                                      BB
# rating_numerico_h2                                              6.45193
# rating_numerico_h1                                              6.21665
# rating_numerico_h0                                              5.43177
# modelo_propension_h2                                            53.9125
# modelo_propension_h1                                            64.2409
# modelo_propension_h0                                             58.238
# guo_nombre                                 MR SANTO DOMINGO GIL ANTONIO
# guo_id_bvd                                                 WW*340485222
# guo_pais                                                           n.d.
# guo_tipo                          Una o más personas físicas o familias
# estado_detallado                                                 Activa
# fecha_cambio_estado                                 2006-01-04 00:00:00
# fecha_constitucion                                  2006-01-04 00:00:00
# p10000_h0                                                        4395.9
# p10000_h1                                                       4012.94
# p10000_h2                                                       3978.07
# p20000_h0                                                       1985.77
# p20000_h1                                                       1972.42
# p20000_h2                                                       1902.23
# p31200_h0                                                       532.231
# p31200_h1                                                       615.484
# p31200_h2                                                       703.993
# p32300_h0                                                       511.651
# p32300_h1                                                       143.155
# p32300_h2                                                       164.588
# p40100_mas_40500_h0                                             6636.59
# p40100_mas_40500_h1                                             5939.01
# p40100_mas_40500_h2                                             5735.58
# p40800_h0                                                      -128.314
# p40800_h1                                                      -122.779
# p40800_h2                                                      -135.549
# p49100_h0                                                       37.4701
# p49100_h1                                                       115.639
# p49100_h2                                                       194.458
# ...
# cod_consolidacion                                                    U1
# rating_grade_h2                                                     CC+
# rating_grade_h1                                                     CC+
# rating_grade_h0                                                     CC+
# rating_numerico_h2                                              2.74606
# rating_numerico_h1                                              2.74606
# rating_numerico_h0                                              2.74606
# modelo_propension_h2                                            16.5209
# modelo_propension_h1                                            16.5209
# modelo_propension_h0                                            16.5209
# guo_nombre
# guo_id_bvd
# guo_pais
# guo_tipo
# estado_detallado      Extinción: La empresa se encuentra en situació...
# fecha_cambio_estado                                 2013-06-30 00:00:00
# fecha_constitucion                                  1984-03-06 00:00:00
# p10000_h0                                                             0
# p10000_h1                                                             0
# p10000_h2                                                             0
# p20000_h0                                                             0
# p20000_h1                                                             0
# p20000_h2                                                             0
# p31200_h0                                                             0
# p31200_h1                                                             0
# p31200_h2                                                             0
# p32300_h0                                                             0
# p32300_h1                                                             0
# p32300_h2                                                             0
# p40100_mas_40500_h0                                                   0
# p40100_mas_40500_h1                                                   0
# p40100_mas_40500_h2                                                   0
# p40800_h0                                                             0
# p40800_h1                                                             0
# p40800_h2                                                             0
# p49100_h0                                                             0
# p49100_h1                                                             0
# p49100_h2                                                             0
# h0_anio                                                            2017
# nif_normalizado                                                33623950
# target_status                                                         1
# ebitda_income                                                       NaN
# debt_ebitda                                                         NaN
# rraa_rrpp                                                           NaN
# log_operating_income                                               -inf
#
#                                                                   49997  \
# id                                                                11902
# nombre_x                   Mecel Cuadros Sociedad Limitada (Extinguida)
# nif                                                           B98101306
# nombre                     Mecel Cuadros Sociedad Limitada (Extinguida)
# provincia                                                      Valencia
# calle                 CALLE THOMAS ALVA EDISON (PQ. TECNOLOGICO), 3 ...
# telefono
# web
# desc_actividad          REALIZACION DE TRABAJOS DE MONTAJES ELECTRICOS.
# cnae                                                               2712
# cod_consolidacion                                                    U1
# rating_grade_h2                                                     CC+
# rating_grade_h1                                                     CC+
# rating_grade_h0                                                     CC+
# rating_numerico_h2                                              2.74606
# rating_numerico_h1                                              2.74606
# rating_numerico_h0                                              2.74606
# modelo_propension_h2                                            16.5209
# modelo_propension_h1                                            16.5209
# modelo_propension_h0                                            16.5209
# guo_nombre
# guo_id_bvd
# guo_pais
# guo_tipo
# estado_detallado      Extinción: La empresa se encuentra en situació...
# fecha_cambio_estado                                 2019-01-21 00:00:00
# fecha_constitucion                                  2008-12-04 00:00:00
# p10000_h0                                                             0
# p10000_h1                                                             0
# p10000_h2                                                             0
# p20000_h0                                                             0
# p20000_h1                                                             0
# p20000_h2                                                             0
# p31200_h0                                                             0
# p31200_h1                                                             0
# p31200_h2                                                             0
# p32300_h0                                                             0
# p32300_h1                                                             0
# p32300_h2                                                             0
# p40100_mas_40500_h0                                                   0
# p40100_mas_40500_h1                                                   0
# p40100_mas_40500_h2                                                   0
# p40800_h0                                                             0
# p40800_h1                                                             0
# p40800_h2                                                             0
# p49100_h0                                                             0
# p49100_h1                                                             0
# p49100_h2                                                             0
# h0_anio                                                            2017
# nif_normalizado                                                98101306
# target_status                                                         1
# ebitda_income                                                       NaN
# debt_ebitda                                                         NaN
# rraa_rrpp                                                           NaN
# log_operating_income                                               -inf
#
#                                                                   49998  \
# id                                                                11903
# nombre_x                                       Gramamed SL (Extinguida)
# nif                                                           B53185245
# nombre                                         Gramamed SL (Extinguida)
# provincia                                                     Castellón
# calle                         CALLE ZINC (PQ EMPRESARIAL CARABONA), S/N
# telefono                                                 +34 96/5893911
# web                                               www.andromedagroup.eu
# desc_actividad        Producción y distribución de especies de acuic...
# cnae                                                               0321
# cod_consolidacion                                                    U1
# rating_grade_h2                                                     CC+
# rating_grade_h1                                                     CC+
# rating_grade_h0                                                     CC+
# rating_numerico_h2                                              2.74606
# rating_numerico_h1                                              2.74606
# rating_numerico_h0                                              2.74606
# modelo_propension_h2                                            16.5209
# modelo_propension_h1                                            16.5209
# modelo_propension_h0                                            16.5209
# guo_nombre
# guo_id_bvd
# guo_pais
# guo_tipo
# estado_detallado      Extinción: La empresa se encuentra en situació...
# fecha_cambio_estado                                 2013-01-16 00:00:00
# fecha_constitucion                                  1997-04-08 00:00:00
# p10000_h0                                                             0
# p10000_h1                                                             0
# p10000_h2                                                             0
# p20000_h0                                                             0
# p20000_h1                                                             0
# p20000_h2                                                             0
# p31200_h0                                                             0
# p31200_h1                                                             0
# p31200_h2                                                             0
# p32300_h0                                                             0
# p32300_h1                                                             0
# p32300_h2                                                             0
# p40100_mas_40500_h0                                                   0
# p40100_mas_40500_h1                                                   0
# p40100_mas_40500_h2                                                   0
# p40800_h0                                                             0
# p40800_h1                                                             0
# p40800_h2                                                             0
# p49100_h0                                                             0
# p49100_h1                                                             0
# p49100_h2                                                             0
# h0_anio                                                            2017
# nif_normalizado                                                53185245
# target_status                                                         1
# ebitda_income                                                       NaN
# debt_ebitda                                                         NaN
# rraa_rrpp                                                           NaN
# log_operating_income                                               -inf
#
#                                                                   49999
# id                                                                11904
# nombre_x                                                 Sistemas RQ SL
# nif                                                           B60380540
# nombre                                                   Sistemas RQ SL
# provincia                                                     Barcelona
# calle                        CALLE DIESEL (POL IND SECTOR AUTOPISTA), 1
# telefono                                                 +34 93/5735320
# web                                               www.ventanaskline.com
# desc_actividad        Fabricación y comercio de puertas y ventanas d...
# cnae                                                               2512
# cod_consolidacion                                                    U1
# rating_grade_h2                                                      CC
# rating_grade_h1                                                    CCC+
# rating_grade_h0                                                      B-
# rating_numerico_h2                                               2.1613
# rating_numerico_h1                                              3.56511
# rating_numerico_h0                                              4.29122
# modelo_propension_h2                                            57.9101
# modelo_propension_h1                                            51.1348
# modelo_propension_h0                                             56.379
# guo_nombre
# guo_id_bvd
# guo_pais
# guo_tipo
# estado_detallado                                                 Activa
# fecha_cambio_estado                                 1993-04-01 00:00:00
# fecha_constitucion                                  1993-04-01 00:00:00
# p10000_h0                                                       3947.93
# p10000_h1                                                       2932.12
# p10000_h2                                                       2554.24
# p20000_h0                                                      -6142.94
# p20000_h1                                                      -6432.67
# p20000_h2                                                       -6448.2
# p31200_h0                                                       650.924
# p31200_h1                                                       331.571
# p31200_h2                                                       561.676
# p32300_h0                                                       989.796
# p32300_h1                                                       578.832
# p32300_h2                                                       259.487
# p40100_mas_40500_h0                                             6635.73
# p40100_mas_40500_h1                                             5591.06
# p40100_mas_40500_h2                                             4970.43
# p40800_h0                                                      -170.303
# p40800_h1                                                      -139.253
# p40800_h2                                                      -111.693
# p49100_h0                                                        394.09
# p49100_h1                                                       114.167
# p49100_h2                                                      -611.305
# h0_anio                                                            2017
# nif_normalizado                                                60380540
# target_status                                                         0
# ebitda_income                                               -0.00448676
# debt_ebitda                                                    -36.2917
# rraa_rrpp                                                      -1.45582
# log_operating_income                                            8.62892
#
# [55 rows x 50000 columns]
